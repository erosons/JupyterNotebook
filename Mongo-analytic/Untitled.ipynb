# %%
import os


source=r"C:\Users\c_seromonsei\Downloads"

# %%
os.listdir(source)
# Out:
# ['.ipynb_checkpoints',
#  '0121_OE_WEB0000000000003414431_09052020_1414_tablet.pdf',
#  '013_1 (1).pdf',
#  '013_1.pdf',
#  '20190513_123111.jpg',
#  '20200421_2szknA6xnwmlMInUpMQ04MPbbIvnxrjP_COVID Policy_ April152020.pdf',
#  '20201026_190605(1).jpg',
#  '5885669AUSD052020-09-20N325130.pdf',
#  '5885669AUSD052020-09-27N358150.pdf',
#  '5885669AUSD052020-10-04N36640 (1).pdf',
#  '5885669AUSD052020-10-04N36640 (2).pdf',
#  '5885669AUSD052020-10-04N36640.pdf',
#  '5885669AUSD052020-10-11N35520 (1).pdf',
#  '5885669AUSD052020-10-11N35520.pdf',
#  '5885669AUSD052020-10-18N16410.pdf',
#  '5885669AUSD052020-10-25N35880.pdf',
#  '6+1(intro)',
#  '9780429294402_preview.pdf',
#  'AlwaysUp_Installer.exe',
#  'Anaconda3-2020.07-Windows-x86_64.exe',
#  'AnimatedBarChartRace.wishyoulizationbarchartrace.1.0.0.0.pbiviz',
#  'Automate_the_Boring_Stuff_onlinematerials_v.2.zip',
#  'baseball_db.zip',
#  'BlueGranite_Columns Measures Example.pbix',
# ...
